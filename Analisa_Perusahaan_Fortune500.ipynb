# %% [markdown]
# <a href="https://colab.research.google.com/github/marveldw/big_data/blob/main/Analisa_Perusahaan_Fortune500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! whoami
# Out:
# marvel

# %%
! hostname
# Out:
# TI3A15Marvellina

# %%
! date
# Out:
# Sat May  9 22:48:29 WIB 2026

# %% [markdown]
# # Tugas: Menganalisa Perusahaan Fortune 500

# %% [markdown]
# Fortune 500 adalah sebuah daftar 500 perusahaan yang diterbitkan setiap tahun oleh majalah bisnis **Fortune**. Daftar ini berisi 500 perusahaan publik terbesar di Amerika Serikat berdasarkan pendapatan kotor mereka dalam tahun fiskal sebelumnya. Dalam daftar ini, perusahaan-perusahaan tersebut diurutkan berdasarkan pendapatan tahunan mereka, dan merupakan indikator utama dalam mengukur keberhasilan dan ukuran perusahaan di pasar Amerika Serikat.
#
# Daftar Fortune 500 sering digunakan sebagai referensi oleh para pelaku bisnis, investor, dan pengamat ekonomi untuk mengetahui tren dalam dunia korporasi, serta untuk memperoleh wawasan tentang kekuatan dan stabilitas perusahaan-perusahaan terkemuka di Amerika Serikat.

# %% [markdown]
# ## Persiapan

# %% [markdown]
# Pastikan telah mengerjakan **latihan**, karena memelukan user dan database yang telah dibuat pada latihan.

# %% [markdown]
# ## Menghubungkan Jupyter Notebook ke Database

# %%
# !pip install ipython-sql SQLAlchemy psycopg2-binary --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: SQLAlchemy in /usr/lib/python3/dist-packages (1.4.50)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: ipython in /usr/lib/python3/dist-packages (from ipython-sql) (8.20.0)
# Collecting SQLAlchemy
#   Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/lib/python3/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/lib/python3/dist-packages (from SQLAlchemy) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/lib/python3/dist-packages (from SQLAlchemy) (4.10.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (5.5.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/lib/python3/dist-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/lib/python3/dist-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /usr/lib/python3/dist-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: pure-eval in /usr/lib/python3/dist-packages (from stack-data->ipython->ipython-sql) (0.0.0)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.6 MB/s eta 0:00:0000:0100:01
# Downloading psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 15.6 MB/s eta 0:00:0000:0100:01
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: sqlparse, SQLAlchemy, psycopg2-binary, prettytable, ipython-sql
#   WARNING: The script sqlformat is installed in '/home/marvel/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed SQLAlchemy-2.0.49 ipython-sql-0.5.0 prettytable-3.17.0 psycopg2-binary-2.9.12 sqlparse-0.5.5

# %%
# %load_ext sql
# %sql postgresql://user01:password@localhost:5432/training
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# SELECT version();
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 1 rows affected.
# [('PostgreSQL 16.13 (Ubuntu 16.13-0ubuntu0.24.04.1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0, 64-bit',)]

# %% [markdown]
# ## Membuat Tabel

# %%
# %%sql
# DROP TABLE IF EXISTS fortune500
# Out:
#  * postgresql://user01:***@localhost:5432/training
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS fortune500 (
#   rank INTEGER,
#   title VARCHAR(100),
#   name VARCHAR(100),
#   ticker VARCHAR(100),
#   url VARCHAR(255),
#   hq VARCHAR(100),
#   sector VARCHAR(50),
#   industry VARCHAR(50),
#   employees INTEGER,
#   revenues INTEGER,
#   revenues_change REAL,
#   profits NUMERIC,
#   profits_change REAL,
#   assets NUMERIC,
#   equity NUMERIC
#
# );
# Out:
#  * postgresql://user01:***@localhost:5432/training
# Done.
# []

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# Dataset yang digunakan adalah dataset perusahaan yang termasuk dalam Fortune 500 pada tahun 2017

# %%
! wget https://www.dropbox.com/s/l3rgaxvdmg0m3ld/fortune500.csv -P dataset
# Out:
# --2026-05-09 23:07:01--  https://www.dropbox.com/s/l3rgaxvdmg0m3ld/fortune500.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/j7sy2rj9y2ja1ul2k74xt/fortune500.csv?rlkey=phx7nafi5hxve2wvpb9bow70e [following]
# --2026-05-09 23:07:02--  https://www.dropbox.com/scl/fi/j7sy2rj9y2ja1ul2k74xt/fortune500.csv?rlkey=phx7nafi5hxve2wvpb9bow70e
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com/cd/0/inline/DAI2N6JxPMY2gwmvTUaEDgjGgfagUb0ODOno1dLRFmBBCT5zpAmnH-whf-QeAw8rz562e_lp5uKMnJsZzJ5egz6YoRrV0J9f0KVuhHSopUKF1uSyewkKfVT_yvUNq2znVOo/file# [following]
# --2026-05-09 23:07:03--  https://uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com/cd/0/inline/DAI2N6JxPMY2gwmvTUaEDgjGgfagUb0ODOno1dLRFmBBCT5zpAmnH-whf-QeAw8rz562e_lp5uKMnJsZzJ5egz6YoRrV0J9f0KVuhHSopUKF1uSyewkKfVT_yvUNq2znVOo/file
# Resolving uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com (uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com (uc42a403ed2e8f8c676d15449169.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81501 (80K) [text/plain]
# Saving to: ‘dataset/fortune500.csv’
#
# fortune500.csv      100%[===================>]  79.59K   314KB/s    in 0.3s
#
# 2026-05-09 23:07:04 (314 KB/s) - ‘dataset/fortune500.csv’ saved [81501/81501]

# %% [markdown]
# ## Import Dataset ke dalam Tabel fortune500

# %% [markdown]
# Buka **PostgreSQL shell** melalui **terminal WSL** dengan perintah berikut

# %% [raw]
# psql -U user01 -d training

# %% [markdown]
# Untuk mengimport dataset ke dalam tabel fortune500, pada **PostgreSQL shell** jalankan perintah berikut

# %% [raw]
# \COPY fortune500 FROM '/home/[user-name]/dataset/fortune500.csv'  DELIMITER ',' NULL 'NA' CSV HEADER;

# %% [markdown]
# catatan:
# **[user-name]** disesuaikan dengan username yang digunaka

# %% [markdown]
# Periksan table fortune500 melalui Jupyter notebook

# %%
# %%sql
# SELECT count(*) FROM fortune500
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 1 rows affected.
# [(500,)]

# %%
# %%sql
# SELECT * FROM fortune500
# LIMIT 5
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 5 rows affected.
# [(1, 'Walmart', 'Wal-Mart Stores, Inc.', 'WMT', 'http://www.walmart.com', 'Bentonville, AR', 'Retailing', 'General Merchandisers', 2300000, 485873, 0.8, Decimal('13643'), -7.2, Decimal('198825'), Decimal('77798')),
#  (2, 'Berkshire Hathaway', 'Berkshire Hathaway Inc.', 'BRKA', 'http://www.berkshirehathaway.com', 'Omaha, NE', 'Financials', 'Insurance: Property and Casualty (Stock)', 367700, 223604, 6.1, Decimal('24074'), 0.0, Decimal('620854'), Decimal('283001')),
#  (3, 'Apple', 'Apple, Inc.', 'AAPL', 'http://www.apple.com', 'Cupertino, CA', 'Technology', 'Computers, Office Equipment', 116000, 215639, -7.7, Decimal('45687'), -14.4, Decimal('321686'), Decimal('128249')),
#  (4, 'Exxon Mobil', 'Exxon Mobil Corporation', 'XOM', 'http://www.exxonmobil.com', 'Irving, TX', 'Energy', 'Petroleum Refining', 72700, 205004, -16.7, Decimal('7840'), -51.5, Decimal('330314'), Decimal('167325')),
#  (5, 'McKesson', 'McKesson Corporation', 'MCK', 'http://www.mckesson.com', 'San Francisco, CA', 'Wholesalers', 'Wholesalers: Health Care', 68000, 192487, 6.2, Decimal('2258'), 53.0, Decimal('56563'), Decimal('8924'))]

# %% [markdown]
# ## Jawab Dan Lengkapi Perintah SQL

# %% [markdown]
# Berikut beberapa tugas SQL yang perlu kamu lengkapi.
# Gunakan dataset Fortune 500 yang sudah di-load ke tabel **fortune500**.
#
# Lengkapi perintah SQL yang bertanda ___

# %% [markdown]
# ### 1. Berapa jumlah record pada tabel fortune500 ?

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM fortune500
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 1 rows affected.
# [(500,)]

# %% [markdown]
# ### 2. Tampilkan Sector apa saja yang ada dalam Fortune500 !

# %% [markdown]
# Gunakan fungsi **distinct** dan urutkan berdasarkan abjad

# %%
# %%sql
#
# SELECT DISTINCT sector
# FROM fortune500
# ORDER BY sector
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 21 rows affected.
# [('Aerospace & Defense',),
#  ('Apparel',),
#  ('Business Services',),
#  ('Chemicals',),
#  ('Energy',),
#  ('Engineering & Construction',),
#  ('Financials',),
#  ('Food & Drug Stores',),
#  ('Food, Beverages & Tobacco',),
#  ('Health Care',),
#  ('Hotels, Restaurants & Leisure',),
#  ('Household Products',),
#  ('Industrials',),
#  ('Materials',),
#  ('Media',),
#  ('Motor Vehicles & Parts',),
#  ('Retailing',),
#  ('Technology',),
#  ('Telecommunications',),
#  ('Transportation',),
#  ('Wholesalers',)]

# %% [markdown]
# ### 3. Tampilkan semua perusahaan yang berada di sektor teknologi

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name dan ticker**

# %%
# %%sql
#
# SELECT rank, title, name, ticker
# FROM fortune500
# WHERE sector = 'Technology'
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 43 rows affected.
# [(3, 'Apple', 'Apple, Inc.', 'AAPL'),
#  (12, 'Amazon.com', 'Amazon.com, Inc.', 'AMZN'),
#  (27, 'Alphabet', 'Alphabet Inc.', 'GOOGL'),
#  (28, 'Microsoft', 'Microsoft Corporation', 'MSFT'),
#  (32, 'IBM', 'International Business Machines Corporation', 'IBM'),
#  (41, 'Dell Technologies', 'Dell Technologies Inc.', None),
#  (47, 'Intel', 'Intel Corporation', 'INTC'),
#  (59, 'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise Company', 'HPE'),
#  (60, 'Cisco Systems', 'Cisco Systems, Inc.', 'CSCO'),
#  (61, 'HP', 'HP Inc.', 'HPQ'),
#  (81, 'Oracle', 'Oracle Corporation', 'ORCL'),
#  (98, 'Facebook', 'Facebook, Inc.', 'FB'),
#  (119, 'Qualcomm', 'Qualcomm Incorporated', 'QCOM'),
#  (144, 'Danaher', 'Danaher Corporation', 'DHR'),
#  (152, 'Jabil Circuit', 'Jabil Circuit, Inc.', 'JBL'),
#  (154, 'Thermo Fisher Scientific', 'Thermo Fisher Scientific Inc.', 'TMO'),
#  (162, 'Xerox', 'Xerox Corporation', 'XRX'),
#  (199, 'CDW', 'CDW Corporation', 'CDW'),
#  (205, 'Cognizant Technology Solutions', 'Cognizant Technology Solutions Corporation', 'CTSH'),
#  (206, 'Texas Instruments', 'Texas Instruments Incorporated', 'TXN'),
#  (217, 'Western Digital', 'Western Digital Corporation', 'WDC'),
#  (226, 'Micron Technology', 'Micron Technology, Inc.', 'MU'),
#  (265, 'Applied Materials', 'Applied Materials, Inc.', 'AMAT'),
#  (268, 'Priceline Group', 'The Priceline Group Inc.', 'PCLN'),
#  (310, 'eBay', 'eBay Inc.', 'EBAY'),
#  (314, 'Netflix', 'Netflix, Inc.', 'NFLX'),
#  (317, 'Expedia', 'Expedia, Inc.', 'EXPE'),
#  (326, 'salesforce.com', 'salesforce.com, inc.', 'CRM'),
#  (363, 'Harris', 'Harris Corporation', 'HRS'),
#  (379, 'Computer Sciences', 'Computer Sciences Corporation', None),
#  (381, 'Leidos Holdings', 'Leidos Holdings, Inc.', 'LDOS'),
#  (387, 'Nvidia', 'NVIDIA Corporation', 'NVDA'),
#  (406, 'Activision Blizzard', 'Activision Blizzard, Inc.', 'ATVI'),
#  (409, 'NCR', 'NCR Corporation', 'NCR'),
#  (414, 'Sanmina', 'Sanmina Corporation', 'SANM'),
#  (424, 'Amphenol', 'Amphenol Corporation', 'APH'),
#  (433, 'Motorola Solutions', 'Motorola Solutions, Inc.', 'MSI'),
#  (440, 'Lam Research', 'Lam Research Corporation', 'LRCX'),
#  (443, 'Adobe Systems', 'Adobe Systems Incorporated', 'ADBE'),
#  (465, 'Symantec', 'Symantec Corporation', 'SYMC'),
#  (468, 'NetApp', 'NetApp, Inc.', 'NTAP'),
#  (481, 'Booz Allen Hamilton Holding', 'Booz Allen Hamilton Holding Corp.', 'BAH'),
#  (498, 'Yahoo', 'Yahoo! Inc.', 'YHOO')]

# %% [markdown]
# ### 4. Tampilkan semua perusahaan yang tidak memiliki kode saham (ticker) !

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name dan ticker**

# %% [markdown]
# ***Petunjuk:***
#
# Gunakan filter **ticker is null**

# %%
# %%sql
#
# SELECT rank, title, name, ticker
# FROM fortune500
# WHERE ticker IS NULL
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 32 rows affected.
# [(33, 'State Farm Insurance Cos.', 'State Farm Insurance Cos.', None),
#  (41, 'Dell Technologies', 'Dell Technologies Inc.', None),
#  (49, 'Albertsons Cos.', 'Albertsons Companies, Inc.', None),
#  (65, 'New York Life Insurance', 'New York Life Insurance Company', None),
#  (68, 'Nationwide', 'Nationwide Mutual Insurance Co.', None),
#  (75, 'Liberty Mutual Insurance Group', 'Liberty Mutual Holding Company Inc.', None),
#  (77, 'Massachusetts Mutual Life Insurance', 'Massachusetts Mutual Life Insurance Company', None),
#  (80, 'TIAA', 'Teachers Insurance and Annuity Association', None),
#  (85, 'Publix Super Markets', 'Publix Super Markets, Inc.', None),
#  (93, 'CHS', 'CHS Inc.', None),
#  (97, 'Northwestern Mutual', 'Northwestern Mutual Life Insurance Company, Inc.', None),
#  (102, 'USAA', 'United Services Automobile Association', None),
#  (209, 'Land O’Lakes', "Land O'Lakes, Inc.", None),
#  (218, 'Guardian Life Ins. Co. of America', 'Guardian Life Ins. Co. of America', None),
#  (222, 'Farmers Insurance Exchange', 'Farmers Insurance Exchange', None),
#  (244, 'Toys “R” Us', 'Toys "R" Us, Inc.', None),
#  (302, 'Pacific Life', 'Pacific Life', None),
#  (315, 'American Family Insurance Group', 'American Family Insurance Group', None),
#  (316, 'Thrivent Financial for Lutherans', 'Thrivent Financial for Lutherans', None),
#  (324, 'Peter Kiewit Sons’', "Peter Kiewit Sons', Inc.", None),
#  (342, 'Mutual of Omaha Insurance', 'Mutual of Omaha Insurance Company', None),
#  (349, 'Western Refining', 'Western Refining, Inc.', None),
#  (379, 'Computer Sciences', 'Computer Sciences Corporation', None),
#  (382, 'Erie Insurance Group', 'Erie Insurance Group', None),
#  (386, 'Harman International Industries', 'Harman International Industries, Incorporated', None),
#  (398, 'Auto-Owners Insurance', 'Auto-Owners Insurance Group', None),
#  (403, 'JetBlue Airways', 'JetBlue Airways Corporation', None),
#  (420, 'Graybar Electric', 'Graybar Electric Company, Inc.', None),
#  (434, 'St. Jude Medical', 'St. Jude Medical, Inc.', None),
#  (483, 'Western & Southern Financial Group', 'Western & Southern Mutual Holding Company', None),
#  (489, 'Airgas', 'Airgas, Inc.', None),
#  (494, 'CH2M Hill', 'CH2M HILL Companies, Ltd.', None)]

# %% [markdown]
# ### 5. Tampilkan semua perusahaan yang memiliki panjang kode saham hanya 2 karakter

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name, ticker dan sector**

# %%
# %%sql
#
# SELECT rank, title, name, ticker, sector
# FROM fortune500
# WHERE LENGTH(ticker) = 2
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 49 rows affected.
# [(8, 'General Motors', 'General Motors Company', 'GM', 'Motor Vehicles & Parts'),
#  (13, 'General Electric', 'General Electric Company', 'GE', 'Industrials'),
#  (14, 'Verizon', 'Verizon Communications Inc.', 'VZ', 'Telecommunications'),
#  (18, 'Kroger', 'The Kroger Company', 'KR', 'Food & Drug Stores'),
#  (23, 'Home Depot', 'The Home Depot, Inc.', 'HD', 'Retailing'),
#  (24, 'Boeing', 'The Boeing Company', 'BA', 'Aerospace & Defense'),
#  (36, 'Procter & Gamble', 'The Procter & Gamble Company', 'PG', 'Household Products'),
#  (64, 'Coca-Cola', 'The Coca-Cola Company', 'KO', 'Food, Beverages & Tobacco'),
#  (70, 'Cigna', 'CIGNA Corporation', 'CI', 'Health Care'),
#  (76, 'Morgan Stanley', 'Morgan Stanley', 'MS', 'Financials'),
#  (78, 'Goldman Sachs Group', 'The Goldman Sachs Group, Inc.', 'GS', 'Financials'),
#  (90, 'General Dynamics', 'General Dynamics Corporation', 'GD', 'Aerospace & Defense'),
#  (98, 'Facebook', 'Facebook, Inc.', 'FB', 'Technology'),
#  (104, 'Philip Morris International', 'Philip Morris International Inc.', 'PM', 'Food, Beverages & Tobacco'),
#  (105, 'Deere', 'Deere & Company', 'DE', 'Industrials'),
#  (113, 'DuPont', 'E.I. du Pont de Nemours and Company', 'DD', 'Chemicals'),
#  (128, 'Dollar General', 'Dollar General Corporation', 'DG', 'Retailing'),
#  (129, 'AutoNation', 'AutoNation, Inc.', 'AN', 'Retailing'),
#  (133, 'International Paper', 'International Paper Company', 'IP', 'Materials'),
#  (145, 'Southern', 'The Southern Company', 'SO', 'Energy'),
#  (148, 'Altria Group', 'Altria Group, Inc.', 'MO', 'Food, Beverages & Tobacco'),
#  (177, 'Bank of New York Mellon', 'The Bank of New York Mellon Corporation', 'BK', 'Financials'),
#  (182, 'Colgate-Palmolive', 'Colgate-Palmolive Company', 'CL', 'Household Products'),
#  (184, 'Goodyear Tire & Rubber', 'The Goodyear Tire & Rubber Company', 'GT', 'Motor Vehicles & Parts'),
#  (196, 'FirstEnergy', 'FirstEnergy Corp.', 'FE', 'Energy'),
#  (201, 'Waste Management', 'Waste Management, Inc.', 'WM', 'Business Services'),
#  (220, 'L Brands', 'L Brands, Inc.', 'LB', 'Retailing'),
#  (226, 'Micron Technology', 'Micron Technology, Inc.', 'MU', 'Technology'),
#  (234, 'Consolidated Edison', 'Consolidated Edison, Inc.', 'ED', 'Energy'),
#  (251, 'Parker-Hannifin', 'Parker-Hannifin Corporation', 'PH', 'Industrials'),
#  (253, 'Estee Lauder', 'The Estee Lauder Companies Inc.', 'EL', 'Household Products'),
#  (267, 'Mastercard', 'Mastercard Incorporated', 'MA', 'Business Services'),
#  (275, 'Praxair', 'Praxair, Inc.', 'PX', 'Chemicals'),
#  (290, 'Laboratory Corp. of America', 'Laboratory Corporation of America Holdings', 'LH', 'Health Care'),
#  (300, 'Alcoa', 'Alcoa Corporation', 'AA', 'Materials'),
#  (320, 'Reliance Steel & Aluminum', 'Reliance Steel & Aluminum Co.', 'RS', 'Materials'),
#  (341, 'Weyerhaeuser', 'Weyerhaeuser Company', 'WY', 'Materials'),
#  (348, 'Foot Locker', 'Foot Locker, Inc.', 'FL', 'Retailing'),
#  (351, 'Dean Foods', 'Dean Foods Company', 'DF', 'Food, Beverages & Tobacco'),
#  (358, 'Eversource Energy', 'Eversource Energy', 'ES', 'Energy'),
#  (371, 'Ralph Lauren', 'Ralph Lauren Corporation', 'RL', 'Apparel'),
#  (401, 'Owens-Illinois', 'Owens-Illinois, Inc.', 'OI', 'Materials'),
#  (436, 'Regions Financial', 'Regions Financial Corporation', 'RF', 'Financials'),
#  (458, 'Owens Corning', 'Owens Corning', 'OC', 'Materials'),
#  (470, 'TravelCenters of America', 'TravelCenters of America LLC', 'TA', 'Retailing'),
#  (478, 'Western Union', 'The Western Union Company', 'WU', 'Business Services'),
#  (480, 'Delek US Holdings', 'Delek US Holdings, Inc.', 'DK', 'Energy'),
#  (482, 'Chemours', 'The Chemours Company', 'CC', 'Chemicals'),
#  (484, 'Celanese', 'Celanese Corporation', 'CE', 'Chemicals')]

# %% [markdown]
# Ada berapa perusahaan yang memiliki panjang kode sahamnya 2?

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM fortune500
# WHERE LENGTH(ticker) = 2
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 1 rows affected.
# [(49,)]

# %% [markdown]
# ### 6. Berapa revenue Apple, Amazon, Facebook, dan Google?

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, revenues, jumlah karyawan (employees)**

# %% [markdown]
# _**Petunjuk:**_
#
# Kode saham (ticker) untuk Apple: AAPL, Amazon: AMZN, Facebook: FB, Google: GOOGL

# %%
# %%sql
#
# SELECT rank, title, revenues, employees
# FROM fortune500
# WHERE ticker IN ('AAPL', 'AMZN', 'FB', 'GOOGL')
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 4 rows affected.
# [(3, 'Apple', 215639, 116000),
#  (12, 'Amazon.com', 135987, 341400),
#  (27, 'Alphabet', 90272, 72053),
#  (98, 'Facebook', 27638, 17048)]

# %% [markdown]
# ### 7. Tampilkan 10 perusahaan yang memiliki pendapatan (revenues) terkecil

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, revenues**

# %% [markdown]
# Catatan: Jumlah revenue yang ditampilkan dalam **juta dolar**

# %%
# %%sql
#
# SELECT rank, title, revenues
# FROM fortune500
# ORDER BY revenues
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [(500, 'ABM Industries', 5145),
#  (499, 'Vistra Energy', 5164),
#  (498, 'Yahoo', 5169),
#  (497, 'Toll Brothers', 5170),
#  (496, 'Michaels Cos.', 5197),
#  (495, 'Big Lots', 5200),
#  (494, 'CH2M Hill', 5236),
#  (493, 'Robert Half International', 5250),
#  (492, 'Rockwell Collins', 5259),
#  (491, 'Liberty Media', 5276)]

# %% [markdown]
# ### 8. Tampilkan perusahaan yang memiliki pendapatan (revenues) diatas 150.000 juta dolar

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, sector, revenues** dan urutkan berdasarkan revenue yang terbesar

# %% [markdown]
# Catatan: Jumlah pendapatan (revenues) yang ada dalam tabel fortune500 sudah dalam satuan juta dolar

# %%
# %%sql
#
# SELECT rank, title, sector, revenues
# FROM fortune500
# WHERE revenues > 150000
# ORDER BY revenues DESC
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [(1, 'Walmart', 'Retailing', 485873),
#  (2, 'Berkshire Hathaway', 'Financials', 223604),
#  (3, 'Apple', 'Technology', 215639),
#  (4, 'Exxon Mobil', 'Energy', 205004),
#  (5, 'McKesson', 'Wholesalers', 192487),
#  (6, 'UnitedHealth Group', 'Health Care', 184840),
#  (7, 'CVS Health', 'Health Care', 177526),
#  (8, 'General Motors', 'Motor Vehicles & Parts', 166380),
#  (9, 'AT&T', 'Telecommunications', 163786),
#  (10, 'Ford Motor', 'Motor Vehicles & Parts', 151800)]

# %% [markdown]
# ### 9. Berapa jumlah perusahaan yang memiliki pendapatan diantara 100.000 dan 200.000 juta dolar ?

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM fortune500
# WHERE revenues BETWEEN 100000 AND 200000
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 1 rows affected.
# [(18,)]

# %% [markdown]
# ### 10. Tampilkan 10 perusahaan yang mengalami penurunan keuntungan terbesar !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, revenues, profits, profits_change dan revenues_change**

# %% [markdown]
# _**Petunjuk:**_
#
# Kolom **profits_change** adalah perubahan keuntungan perusahaan dibandingkan tahun sebelumnya. Jika bernilai positif maka perusahaan tersebut memiliki keuntungan, dan jika negatif maka perusahaan tersebut mengalami penurunan keuntungan.

# %%
# %%sql
#
# SELECT title, sector, revenues, profits, profits_change, revenues_change
# FROM fortune500
# ORDER BY profits_change
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('Windstream Holdings', 'Telecommunications', 5387, Decimal('-383.5'), -1499.6, -6.6),
#  ('Community Health Systems', 'Health Care', 21374, Decimal('-1721'), -1189.2, -5.8),
#  ('FirstEnergy', 'Energy', 14156, Decimal('-6177'), -1168.7, -3.1),
#  ('Delek US Holdings', 'Energy', 5414, Decimal('-153.7'), -892.3, -6.0),
#  ('NGL Energy Partners', 'Energy', 11742, Decimal('-198.9'), -633.2, -30.1),
#  ('Global Partners', 'Wholesalers', 8240, Decimal('-199.4'), -557.8, -20.1),
#  ('Univar', 'Wholesalers', 8074, Decimal('-68.4'), -514.5, -10.1),
#  ('Staples', 'Retailing', 20217, Decimal('-1497'), -494.8, -4.0),
#  ('AES', 'Energy', 14287, Decimal('-1130'), -469.3, -4.5),
#  ('R.R. Donnelley & Sons', 'Media', 6896, Decimal('-495.9'), -428.2, -38.7)]

# %% [markdown]
# ### 11. Tampilkan 10 perusahaan yang sedang naik daun (memiliki pertumbuhan pendapatan tertinggi) !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, revenues, profits, profits_change dan revenues_change**

# %% [markdown]
# _**Petunjuk:**_
#
# Kolom **revenues_change** adalah perubahan keuntungan perusahaan dibandingkan tahun sebelumnya dalam persentase. Jika bernilai positif maka perusahaan tersebut memiliki keuntungan, dan jika negatif maka perusahaan tersebut mengalami penurunan keuntungan.

# %%
# %%sql
#
# SELECT title, sector, revenues, profits, profits_change, revenues_change
# FROM fortune500
# ORDER BY revenues_change DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('Charter Communications', 'Telecommunications', 29003, Decimal('3522'), None, 197.3),
#  ('Newell Brands', 'Household Products', 13264, Decimal('527.8'), 50.8, 122.1),
#  ('Albertsons Cos.', 'Food & Drug Stores', 58734, Decimal('-502.2'), None, 115.9),
#  ('Olin', 'Chemicals', 5551, Decimal('-3.9'), None, 94.5),
#  ('TreeHouse Foods', 'Food, Beverages & Tobacco', 6175, Decimal('-228.6'), -298.9, 92.6),
#  ('XPO Logistics', 'Transportation', 14619, Decimal('69'), None, 91.8),
#  ('CalAtlantic Group', 'Engineering & Construction', 6477, Decimal('484.7'), 127.0, 83.0),
#  ('Centene', 'Health Care', 40721, Decimal('562'), 58.3, 78.6),
#  ('Builders FirstSource', 'Materials', 6367, Decimal('144.3'), None, 78.6),
#  ('Tesla', 'Motor Vehicles & Parts', 7000, Decimal('-674.9'), None, 73.0)]

# %% [markdown]
# ### 12. Tampilkan 10 perusahaan yang memiliki rasio profit terhadap pendapatan (Profit Margin) tertinggi

# %% [markdown]
# Output yang ditampilkan adalah **name, sector, revenues, profits dan profit_margin**

# %% [markdown]
# _**Petunjuk:**_
#
# **profit_margin** adalah rasio profit terhadap pendapatan, yang dihitung dalam persentase profits dibagi revenues. Rumusnya
#
#             ROUND((profits / revenues) * 100, 2)
#
# Buang terlebih dahulu profits dan revenues yang bernilai null

# %%
# %%sql
# SELECT name,
#        sector,
#        revenues,
#        profits,
#        ROUND((profits / revenues) * 100, 2) AS profit_margin
# FROM fortune500
# WHERE profits IS NOT NULL AND revenues IS NOT NULL
# ORDER BY profit_margin DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('eBay Inc.', 'Technology', 8979, Decimal('7266'), Decimal('80.92')),
#  ('Altria Group, Inc.', 'Food, Beverages & Tobacco', 19337, Decimal('14239'), Decimal('73.64')),
#  ('Baxter International Inc.', 'Health Care', 10163, Decimal('4965'), Decimal('48.85')),
#  ('Reynolds American Inc.', 'Food, Beverages & Tobacco', 12503, Decimal('6073'), Decimal('48.57')),
#  ('Symantec Corporation', 'Technology', 5568, Decimal('2488'), Decimal('44.68')),
#  ('Gilead Sciences, Inc.', 'Health Care', 30390, Decimal('13501'), Decimal('44.43')),
#  ('Visa Inc.', 'Business Services', 15082, Decimal('5991'), Decimal('39.72')),
#  ('Corning Incorporated', 'Industrials', 9390, Decimal('3695'), Decimal('39.35')),
#  ('Mastercard Incorporated', 'Business Services', 10776, Decimal('4059'), Decimal('37.67')),
#  ('S&P Global Inc.', 'Business Services', 5661, Decimal('2106'), Decimal('37.20'))]

# %% [markdown]
# ### 13. Sektor mana yang paling efisien menghasilkan profit dibandingkan asetnya ?

# %% [markdown]
# Output yang ditampilkan adalah **sector, return_on_assets**

# %% [markdown]
# _**Petunjuk:**_
#
# **return_on_assets** adalah perbandingan antara profit dan asset. Hal ini untuk menunjukkan efisiensi operasional sektor, karena aset fisik lebih kecil tapi menghasilkan profit besar. Gunakan formula berikut untuk menghitung return_on_assets
#
#             ROUND(SUM(profits) / NULLIF(SUM(assets), 0) * 100, 2)

# %%
# %%sql
#
# SELECT sector,
#        ROUND(SUM(profits) / NULLIF(SUM(assets), 0) * 100, 2) AS return_on_assets
# FROM fortune500
# GROUP BY sector
# ORDER BY return_on_assets DESC
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 21 rows affected.
# [('Apparel', Decimal('11.42')),
#  ('Hotels, Restaurants & Leisure', Decimal('8.64')),
#  ('Technology', Decimal('8.55')),
#  ('Food, Beverages & Tobacco', Decimal('8.07')),
#  ('Household Products', Decimal('7.12')),
#  ('Retailing', Decimal('6.85')),
#  ('Health Care', Decimal('6.59')),
#  ('Aerospace & Defense', Decimal('6.56')),
#  ('Transportation', Decimal('6.44')),
#  ('Media', Decimal('5.90')),
#  ('Business Services', Decimal('5.89')),
#  ('Chemicals', Decimal('5.64')),
#  ('Food & Drug Stores', Decimal('4.94')),
#  ('Engineering & Construction', Decimal('4.76')),
#  ('Industrials', Decimal('4.31')),
#  ('Wholesalers', Decimal('4.18')),
#  ('Telecommunications', Decimal('3.59')),
#  ('Motor Vehicles & Parts', Decimal('3.23')),
#  ('Materials', Decimal('2.52')),
#  ('Financials', Decimal('0.85')),
#  ('Energy', Decimal('0.02'))]

# %% [markdown]
# ### 14. Kota mana yang paling banyak menjadi markas perusahaan Fortune 500?

# %% [markdown]
# Output yang ditampilkan adalah **hq dan total_companies**

# %% [markdown]
# _**Petunjuk:**_
#
# **hq** adalah kota yang dijadikan kantor utama bagi perusahaan.

# %%
# %%sql
#
# SELECT hq, COUNT(*) AS total_companies
# FROM fortune500
# GROUP BY hq
# ORDER BY total_companies DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('New York, NY', 45),
#  ('Houston, TX', 18),
#  ('Atlanta, GA', 12),
#  ('Chicago, IL', 10),
#  ('Dallas, TX', 10),
#  ('San Francisco, CA', 6),
#  ('Minneapolis, MN', 6),
#  ('Cincinnati, OH', 6),
#  ('Richmond, VA', 6),
#  ('St. Louis, MO', 6)]

# %% [markdown]
# ### 15. Tampilkan 10 perusahaan yang memiliki struktur keuangan paling kuat (rasio equity/assets terbesar)?

# %% [markdown]
# Output yang ditampilkan adalah **title, sector dan equity_ratio**

# %% [markdown]
# _**Petunjuk:**_
#
# Perusahaan dengan **rasio equity** tinggi menunjukkan stabilitas keuangan dan ketergantungan rendah pada utang. Untuk menghitung rasio equity gunakan formula berikut:
#
#             ROUND((equity / NULLIF(assets, 0)) * 100, 2)

# %%
# %%sql
#
# SELECT title,
#        sector,
#        ROUND((equity / NULLIF(assets, 0)) * 100, 2) AS equity_ratio
# FROM fortune500
# WHERE equity IS NOT NULL
# ORDER BY equity_ratio DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('Facebook', 'Technology', Decimal('91.12')),
#  ('Alphabet', 'Technology', Decimal('83.01')),
#  ('Publix Super Markets', 'Food & Drug Stores', Decimal('77.15')),
#  ('Cognizant Technology Solutions', 'Technology', Decimal('75.22')),
#  ('News Corp.', 'Media', Decimal('74.69')),
#  ('Franklin Resources', 'Financials', Decimal('74.14')),
#  ('Foot Locker', 'Retailing', Decimal('70.57')),
#  ('Hormel Foods', 'Food, Beverages & Tobacco', Decimal('69.83')),
#  ('Seaboard', 'Food, Beverages & Tobacco', Decimal('66.50')),
#  ('Baker Hughes', 'Energy', Decimal('66.49'))]

# %% [markdown]
# ### 16. Tampilkan 10 sektor dengan pertumbuhan pendapatan rata-rata tertinggi !

# %% [markdown]
# Output yang ditampilkan adalah **sector, dan avg_revenue_growth**

# %% [markdown]
# _**Petunjuk:**_
#
# avg_revenue_growth dihitung dengan menggunakan rata-rata revenues_change

# %%
# %%sql
#
# SELECT sector,
#        AVG(revenues_change) AS avg_revenue_growth
# FROM fortune500
# GROUP BY sector
# ORDER BY avg_revenue_growth DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('Telecommunications', 28.380000258982182),
#  ('Food & Drug Stores', 22.27142867020198),
#  ('Engineering & Construction', 13.369230835483624),
#  ('Motor Vehicles & Parts', 11.29999996556176),
#  ('Health Care', 10.223684105826052),
#  ('Household Products', 8.774999976158142),
#  ('Materials', 8.042105285744919),
#  ('Technology', 7.162790740991747),
#  ('Business Services', 5.589999961853027),
#  ('Transportation', 5.476470708847046)]

# %% [markdown]
# ### 17. Tampilkan 10 perusahaan dengan aset tertinggi !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, hq, assets**

# %%
# %%sql
#
# SELECT title, sector, hq, assets
# FROM fortune500
# ORDER BY assets DESC
# LIMIT 10
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 10 rows affected.
# [('Fannie Mae', 'Financials', 'Washington, DC', Decimal('3287968')),
#  ('J.P. Morgan Chase', 'Financials', 'New York, NY', Decimal('2490972')),
#  ('Bank of America Corp.', 'Financials', 'Charlotte, NC', Decimal('2187702')),
#  ('Freddie Mac', 'Financials', 'McLean, VA', Decimal('2023376')),
#  ('Wells Fargo', 'Financials', 'San Francisco, CA', Decimal('1930115')),
#  ('Citigroup', 'Financials', 'New York, NY', Decimal('1792077')),
#  ('MetLife', 'Financials', 'New York, NY', Decimal('898764')),
#  ('Goldman Sachs Group', 'Financials', 'New York, NY', Decimal('860165')),
#  ('Morgan Stanley', 'Financials', 'New York, NY', Decimal('814949')),
#  ('Prudential Financial', 'Financials', 'Newark, NJ', Decimal('783962'))]

# %% [markdown]
# ### 18. Hitung jumlah kelompok perusahaan small, medium and big
#
# Pengelompokkan tersebut berdasarkan perhitungan jumlah karyawan, dengan aturan sebagai berikut
# - SMALL --> jumlah karyawan lebih kecil atau sama dengan 200
# - MEDIUM --> jumlah karyawan lebih besar dari 200 dan lebih kecil atau sama dengan 1000
# - BIG --> jumlah karyawan lebih besar dari 1000
#
#
# ***Petunjuk***
# - gunakan case when
# - gunakan nested query (query di dalam query) untuk mengelompokkan

# %%
# %%sql
#
# SELECT company_type, COUNT(*) AS num_company
# FROM
# (
#   SELECT
#         title,
#         CASE
#             WHEN employees <= 200 THEN 'SMALL'
#             WHEN employees > 200 AND employees <= 1000 THEN 'MEDIUM'
#             ELSE 'BIG'
#         END AS company_type
#   FROM fortune500
# ) t
# -- Kelompokkan dan urutkan berdasarkan company_type
# GROUP BY company_type
# ORDER BY company_type
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 3 rows affected.
# [('BIG', 498), ('MEDIUM', 1), ('SMALL', 1)]

# %% [markdown]
# ### 19. Hitung rata-rata revenue per employee yang dikelompokkan berdasarkan sector
#
# Output yang ditampilkan **sector dan rev_per_employee**
#
# ***Petunjuk***
#
# Rata-rata revenue per employee --> avg(revenues/employees::numeric)

# %%
# %%sql
#
# SELECT sector, AVG(revenues/employees::numeric) AS rev_per_employee
# FROM fortune500
# GROUP BY sector
# ORDER BY rev_per_employee DESC
# Out:
#  * postgresql://user01:***@localhost:5432/training
# 21 rows affected.
# [('Materials', Decimal('4.75758351554488369167')),
#  ('Energy', Decimal('1.82601423325242362195')),
#  ('Financials', Decimal('1.72638470140972568700')),
#  ('Wholesalers', Decimal('1.41324581189371202678')),
#  ('Engineering & Construction', Decimal('0.86116376673874818555')),
#  ('Food, Beverages & Tobacco', Decimal('0.83088475939249850372')),
#  ('Media', Decimal('0.79561866565463184108')),
#  ('Health Care', Decimal('0.79053286919681465178')),
#  ('Telecommunications', Decimal('0.62958997279187493604')),
#  ('Chemicals', Decimal('0.59549976658074458280')),
#  ('Technology', Decimal('0.57311847693359764307')),
#  ('Business Services', Decimal('0.42010994210166630178')),
#  ('Transportation', Decimal('0.40365352477329589012')),
#  ('Aerospace & Defense', Decimal('0.36671499248628270960')),
#  ('Industrials', Decimal('0.36148543376146347043')),
#  ('Retailing', Decimal('0.36019456092078082945')),
#  ('Household Products', Decimal('0.35557338969595350494')),
#  ('Motor Vehicles & Parts', Decimal('0.34252712424659522769')),
#  ('Food & Drug Stores', Decimal('0.30799950410060207070')),
#  ('Apparel', Decimal('0.27865942976680063809')),
#  ('Hotels, Restaurants & Leisure', Decimal('0.09498718151056814829'))]

# %% [markdown]
# ### 20. Tampilkan 5 industri yang memiliki keuntungan negatif (rugi) paling banyak?
#
# Output yang ditampilkan **industry dan num_companies**

# %%
# %%sql
# %%sql
#
# SELECT industry, COUNT(*) AS num_companies
# FROM fortune500
# WHERE profits < 0
# GROUP BY industry
# ORDER BY num_companies DESC
# LIMIT 5
# -- your code is here
# Out:
#  * postgresql://user01:***@localhost:5432/training
# (psycopg2.errors.SyntaxError) syntax error at or near "%%"
# LINE 1: %%sql
#         ^
#
# [SQL: %%%%sql
#
# SELECT industry, COUNT(*) AS num_companies
# FROM fortune500
# WHERE profits < 0
# GROUP BY industry
# ORDER BY num_companies DESC
# LIMIT 5
# -- your code is here]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# # JIKA SUDAH SELESAI, JANGAN LUPA DISAVE #
