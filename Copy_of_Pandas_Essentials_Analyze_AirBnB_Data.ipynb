# %% [markdown]
# <a href="https://colab.research.google.com/github/marveldw/big_data/blob/main/Copy_of_Pandas_Essentials_Analyze_AirBnB_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 02 - DataFrame Basics
#
# Untuk rangkaian latihan ini kita akan mengolah dan menganalisis data AirBnB New York. Data didapatkan dari link ini (https://www.kaggle.com/dgomonov/data-exploration-on-nyc-airbnb) dengan beberapa penyesuaian.
#
# Dalam Lab 02 ini kita akan melakukan loading file csv, kemudian melakukan eksplorasi data untuk melihat langkah data cleansing apa yang perlu dilakukan.
#
# Beberapa hal yang perlu diperhatikan:
#
# 1. Adakah kolom yang tidak diperlukan, yang bisa dihapus?
# 2. Adakah data yang hilang/null? Apa yang harus kita lakukan terhadapnya?
# 3. Apakah ada data duplikat, dan apa yang harus dilakukan untuk mengolahnya?

# %% [markdown]
# Langkah pengolahan dataset
# - Loading csv file
# - Quick check
# - Akses dengan berbagai metode
#
# Berikut ini beberapa pertanyaan untuk latihan :
# 1. Ada berapa row dan berapa kolom data yang di-load?
# 2. Apa saja nama kolomnya?
# 3. Tampilkan data dari baris ke 11 sampai ke 20
# 4. Tampilkan data dari kolom ke 3 sampai ke 6
# 5. Berapa nilai rata-rata, maksimum dan minimum untuk kolom2 tertentu?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading data dari file csv.

# %%
filename = 'https://raw.githubusercontent.com/urfie/DataAnalytics/main/airbnb_nyc_toclean.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    index    id                                              name  host_id  \
# 0      1  2595                             Skylit Midtown Castle     2845
# 1      2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2      3  3831                   Cozy Entire Floor of Brownstone     4869
# 3      4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4      5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood  latitude  longitude        room_type  price  \
# 0     Jennifer       Midtown  40.75362  -73.98377  Entire home/apt    225
# 1    Elisabeth        Harlem  40.80902  -73.94190     Private room    150
# 2  LisaRoxanne  Clinton Hill  40.68514  -73.95976  Entire home/apt     89
# 3        Laura   East Harlem  40.79851  -73.94399  Entire home/apt     80
# 4        Chris   Murray Hill  40.74767  -73.97500  Entire home/apt    200
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                 45  2019-05-21               0.38
# 1               3                  0         NaN                NaN
# 2               1                270  2019-07-05               4.64
# 3              10                  9  2018-11-19               0.10
# 4               3                 74  2019-06-22               0.59
#
#    calculated_host_listings_count  availability_365
# 0                               2               355
# 1                               1               365
# 2                               1               194
# 3                               1                 0
# 4                               1               129

# %% [markdown]
# Melakukan *Quick Checking* untuk melihat sekilas profil dataset.

# %%
# 1. tampilkan shape (dimensi) dari DataFrame
print("Dimensi Data:", df.shape)
# Out:
# Dimensi Data: (48945, 16)

# %%
# 2. tampilkan nama kolom dari DataFrame
print("Nama Kolom:", df.columns.tolist())
# Out:
# Nama Kolom: ['index', 'id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
# 3. Tampilkan data dari baris ke 11 sampai ke 20
display(df.iloc[10:20])
# Out:
#     index    id                                              name  host_id  \
# 10     11  5441                   Central Manhattan/near Broadway     7989
# 11     12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 12     13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 13     14  6090                     West Village Nest - Superhost    11975
# 14     15  6848                  Only 2 stops to Manhattan studio    15991
# 15     16  7097                 Perfect for Your Parents + Garden    17571
# 16     17  7322                                   Chelsea Perfect    18946
# 17     18  7726   Hip Historic Brownstone Apartment with Backyard    20950
# 18     19  7750                 Huge 2 BR Upper East  Cental Park    17985
# 19     20  7801                  Sweet and Spacious Brooklyn Loft    21207
#
#            host_name    neighbourhood  latitude  longitude        room_type  \
# 10              Kate   Hell's Kitchen  40.76076  -73.98867     Private room
# 11            Laurie      South Slope  40.66829  -73.98779     Private room
# 12           Claudio  Upper West Side  40.79826  -73.96113     Private room
# 13             Alina     West Village  40.73530  -74.00525  Entire home/apt
# 14     Allen & Irina     Williamsburg  40.70837  -73.95352  Entire home/apt
# 15              Jane      Fort Greene  40.69169  -73.97185  Entire home/apt
# 16              Doti          Chelsea  40.74192  -73.99501     Private room
# 17  Adam And Charity    Crown Heights  40.67592  -73.94694  Entire home/apt
# 18              Sing      East Harlem  40.79685  -73.94872  Entire home/apt
# 19             Chaya     Williamsburg  40.71842  -73.95718  Entire home/apt
#
#     price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 10     85               2                188  2019-06-23               1.50
# 11     89               4                167  2019-06-24               1.34
# 12     85               2                113  2019-07-05               0.91
# 13    120              90                 27  2018-10-31               0.22
# 14    140               2                148  2019-06-29               1.20
# 15    215               2                198  2019-06-28               1.72
# 16    140               1                260  2019-07-01               2.12
# 17     99               3                 53  2019-06-22               4.44
# 18    190               7                  0         NaN                NaN
# 19    299               3                  9  2011-12-28               0.07
#
#     calculated_host_listings_count  availability_365
# 10                               1                39
# 11                               3               314
# 12                               1               333
# 13                               1                 0
# 14                               1                46
# 15                               1               321
# 16                               1                12
# 17                               1                21
# 18                               2               249
# 19                               1                 0

# %%
# 4. Tampilkan data dari kolom ke 3 sampai ke 6
display(df.iloc[:, 2:6])
# Out:
#                                                    name  host_id  \
# 0                                 Skylit Midtown Castle     2845
# 1                   THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2                       Cozy Entire Floor of Brownstone     4869
# 3      Entire Apt: Spacious Studio/Loft by central park     7192
# 4             Large Cozy 1 BR Apartment In Midtown East     7322
# ...                                                 ...      ...
# 48940                 Perfect for Your Parents + Garden    17571
# 48941                                   Chelsea Perfect    18946
# 48942   Hip Historic Brownstone Apartment with Backyard    20950
# 48943                 Huge 2 BR Upper East  Cental Park    17985
# 48944                  Sweet and Spacious Brooklyn Loft    21207
#
#               host_name  neighbourhood
# 0              Jennifer        Midtown
# 1             Elisabeth         Harlem
# 2           LisaRoxanne   Clinton Hill
# 3                 Laura    East Harlem
# 4                 Chris    Murray Hill
# ...                 ...            ...
# 48940              Jane    Fort Greene
# 48941              Doti        Chelsea
# 48942  Adam And Charity  Crown Heights
# 48943              Sing    East Harlem
# 48944             Chaya   Williamsburg
#
# [48945 rows x 4 columns]

# %%
# tampilkan informasi kolom dari DataFrame
# hints: gunakan fungsi info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48945 entries, 0 to 48944
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           48945 non-null  int64
#  1   id                              48945 non-null  int64
#  2   name                            48929 non-null  object
#  3   host_id                         48945 non-null  int64
#  4   host_name                       48924 non-null  object
#  5   neighbourhood                   48943 non-null  object
#  6   latitude                        48942 non-null  float64
#  7   longitude                       48942 non-null  float64
#  8   room_type                       48945 non-null  object
#  9   price                           48945 non-null  int64
#  10  minimum_nights                  48945 non-null  int64
#  11  number_of_reviews               48945 non-null  int64
#  12  last_review                     38884 non-null  object
#  13  reviews_per_month               38884 non-null  float64
#  14  calculated_host_listings_count  48945 non-null  int64
#  15  availability_365                48945 non-null  int64
# dtypes: float64(3), int64(8), object(5)
# memory usage: 6.0+ MB

# %%
#5. tampilkan nilai statistik setiap kolom dari DataFrame
display(df.describe())
# Out:
#               index            id       host_id      latitude     longitude  \
# count  48945.000000  4.894500e+04  4.894500e+04  48942.000000  48942.000000
# mean   24453.008172  1.900145e+07  6.755608e+07     40.728964    -73.952185
# std    14129.334656  1.099403e+07  7.859802e+07      0.054529      0.046141
# min        1.000000  2.539000e+03  2.438000e+03     40.499790    -74.244420
# 25%    12217.000000  9.452887e+06  7.780845e+06     40.690100    -73.983080
# 50%    24453.000000  1.967051e+07  3.071956e+07     40.723090    -73.955690
# 75%    36689.000000  2.914855e+07  1.074344e+08     40.763130    -73.936312
# max    48925.000000  3.648725e+07  2.743213e+08     40.913060    -73.712990
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48945.000000    48945.000000       48945.000000       38884.000000
# mean     152.693166        7.033323          23.357197           1.373237
# std      240.038636       20.509578          44.725933           1.680072
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48945.000000      48945.000000
# mean                         7.138012        112.787496
# std                         32.936220        131.621721
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# #Lab 03 - Handling Missing & Duplicates
#
# Dalam lab ini kita akan melakukan eksplorasi dan pengolahan data terkait missing dan duplicate. Langkah yang akan kita lakukan :
# - Check missing values
# - Check duplicate values
# - Check unique values
#
#
# Berikut ini beberapa pertanyaan untuk latihan :
# 1. Ada berapa data yang null untuk masing-masing kolom?
# 2. Adakah data duplikat (row yang persis sama)?
# 3. Adakah kolom  yang tidak boleh duplikat?
# 4. Berapa jumlah unique value untuk kolom room_type, neighbourhood, dan availability_365 ?
# 5. Apa yang perlu dilakukan untuk kasus-kasus di atas?

# %% [markdown]
# ##Missing Values

# %%
# 1. tampilkan berapa nilai NaN dari setiap kolom
# hints: gunakan fungsi isna() dan sum()
print("Jumlah Missing Values per Kolom:\n", df.isna().sum())
# Out:
# Jumlah Missing Values per Kolom:
#  index                                 0
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood                         2
# latitude                              3
# longitude                             3
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10061
# reviews_per_month                 10061
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# memberi nilai NaN dengan 0 pada kolom reviews_per_month
df['reviews_per_month'].fillna(0, inplace=True)

# mengecek kembali apakan kolom reviews_per_month masih ada yang bernilai NaN
print("Missing values di reviews_per_month:", df['reviews_per_month'].isna().sum())
# Out:
# Missing values di reviews_per_month: 0
# /tmp/ipykernel_1115/4202902897.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews_per_month'].fillna(0, inplace=True)

# %%
#drop rows with missing neighbourhood, long, or lat column
df.dropna(subset=['neighbourhood', 'longitude', 'latitude'], how='any', inplace=True)

# %% [markdown]
# ##Duplicate Values

# %%
# 2. Adakah data duplikat (row yang persis sama)? Check duplicate rows
print("Jumlah Baris Duplikat:", df.duplicated().sum())
display(df.loc[df.duplicated(keep=False)])
# Out:
# Jumlah Baris Duplikat: 20
#        index    id                                              name  host_id  \
# 0          1  2595                             Skylit Midtown Castle     2845
# 1          2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2          3  3831                   Cozy Entire Floor of Brownstone     4869
# 3          4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4          5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 5          6  5121                                   BlissArtsSpace!     7356
# 6          7  5178                  Large Furnished Room Near B'way      8967
# 7          8  5203                Cozy Clean Guest Room - Family Apt     7490
# 8          9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 9         10  5295                  Beautiful 1br on Upper West Side     7702
# 10        11  5441                   Central Manhattan/near Broadway     7989
# 11        12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 12        13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 13        14  6090                     West Village Nest - Superhost    11975
# 14        15  6848                  Only 2 stops to Manhattan studio    15991
# 15        16  7097                 Perfect for Your Parents + Garden    17571
# 16        17  7322                                   Chelsea Perfect    18946
# 17        18  7726   Hip Historic Brownstone Apartment with Backyard    20950
# 18        19  7750                 Huge 2 BR Upper East  Cental Park    17985
# 19        20  7801                  Sweet and Spacious Brooklyn Loft    21207
# 48925      1  2595                             Skylit Midtown Castle     2845
# 48926      2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 48927      3  3831                   Cozy Entire Floor of Brownstone     4869
# 48928      4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 48929      5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48930      6  5121                                   BlissArtsSpace!     7356
# 48931      7  5178                  Large Furnished Room Near B'way      8967
# 48932      8  5203                Cozy Clean Guest Room - Family Apt     7490
# 48933      9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48934     10  5295                  Beautiful 1br on Upper West Side     7702
# 48935     11  5441                   Central Manhattan/near Broadway     7989
# 48936     12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48937     13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48938     14  6090                     West Village Nest - Superhost    11975
# 48939     15  6848                  Only 2 stops to Manhattan studio    15991
# 48940     16  7097                 Perfect for Your Parents + Garden    17571
# 48941     17  7322                                   Chelsea Perfect    18946
# 48942     18  7726   Hip Historic Brownstone Apartment with Backyard    20950
# 48943     19  7750                 Huge 2 BR Upper East  Cental Park    17985
# 48944     20  7801                  Sweet and Spacious Brooklyn Loft    21207
#
#               host_name       neighbourhood  latitude  longitude  \
# 0              Jennifer             Midtown  40.75362  -73.98377
# 1             Elisabeth              Harlem  40.80902  -73.94190
# 2           LisaRoxanne        Clinton Hill  40.68514  -73.95976
# 3                 Laura         East Harlem  40.79851  -73.94399
# 4                 Chris         Murray Hill  40.74767  -73.97500
# 5                 Garon  Bedford-Stuyvesant  40.68688  -73.95596
# 6              Shunichi      Hell's Kitchen  40.76489  -73.98493
# 7             MaryEllen     Upper West Side  40.80178  -73.96723
# 8                   Ben           Chinatown  40.71344  -73.99037
# 9                  Lena     Upper West Side  40.80316  -73.96545
# 10                 Kate      Hell's Kitchen  40.76076  -73.98867
# 11               Laurie         South Slope  40.66829  -73.98779
# 12              Claudio     Upper West Side  40.79826  -73.96113
# 13                Alina        West Village  40.73530  -74.00525
# 14        Allen & Irina        Williamsburg  40.70837  -73.95352
# 15                 Jane         Fort Greene  40.69169  -73.97185
# 16                 Doti             Chelsea  40.74192  -73.99501
# 17     Adam And Charity       Crown Heights  40.67592  -73.94694
# 18                 Sing         East Harlem  40.79685  -73.94872
# 19                Chaya        Williamsburg  40.71842  -73.95718
# 48925          Jennifer             Midtown  40.75362  -73.98377
# 48926         Elisabeth              Harlem  40.80902  -73.94190
# 48927       LisaRoxanne        Clinton Hill  40.68514  -73.95976
# 48928             Laura         East Harlem  40.79851  -73.94399
# 48929             Chris         Murray Hill  40.74767  -73.97500
# 48930             Garon  Bedford-Stuyvesant  40.68688  -73.95596
# 48931          Shunichi      Hell's Kitchen  40.76489  -73.98493
# 48932         MaryEllen     Upper West Side  40.80178  -73.96723
# 48933               Ben           Chinatown  40.71344  -73.99037
# 48934              Lena     Upper West Side  40.80316  -73.96545
# 48935              Kate      Hell's Kitchen  40.76076  -73.98867
# 48936            Laurie         South Slope  40.66829  -73.98779
# 48937           Claudio     Upper West Side  40.79826  -73.96113
# 48938             Alina        West Village  40.73530  -74.00525
# 48939     Allen & Irina        Williamsburg  40.70837  -73.95352
# 48940              Jane         Fort Greene  40.69169  -73.97185
# 48941              Doti             Chelsea  40.74192  -73.99501
# 48942  Adam And Charity       Crown Heights  40.67592  -73.94694
# 48943              Sing         East Harlem  40.79685  -73.94872
# 48944             Chaya        Williamsburg  40.71842  -73.95718
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    225               1                 45  2019-05-21
# 1         Private room    150               3                  0         NaN
# 2      Entire home/apt     89               1                270  2019-07-05
# 3      Entire home/apt     80              10                  9  2018-11-19
# 4      Entire home/apt    200               3                 74  2019-06-22
# 5         Private room     60              45                 49  2017-10-05
# 6         Private room     79               2                430  2019-06-24
# 7         Private room     79               2                118  2017-07-21
# 8      Entire home/apt    150               1                160  2019-06-09
# 9      Entire home/apt    135               5                 53  2019-06-22
# 10        Private room     85               2                188  2019-06-23
# 11        Private room     89               4                167  2019-06-24
# 12        Private room     85               2                113  2019-07-05
# 13     Entire home/apt    120              90                 27  2018-10-31
# 14     Entire home/apt    140               2                148  2019-06-29
# 15     Entire home/apt    215               2                198  2019-06-28
# 16        Private room    140               1                260  2019-07-01
# 17     Entire home/apt     99               3                 53  2019-06-22
# 18     Entire home/apt    190               7                  0         NaN
# 19     Entire home/apt    299               3                  9  2011-12-28
# 48925  Entire home/apt    225               1                 45  2019-05-21
# 48926     Private room    150               3                  0         NaN
# 48927  Entire home/apt     89               1                270  2019-07-05
# 48928  Entire home/apt     80              10                  9  2018-11-19
# 48929  Entire home/apt    200               3                 74  2019-06-22
# 48930     Private room     60              45                 49  2017-10-05
# 48931     Private room     79               2                430  2019-06-24
# 48932     Private room     79               2                118  2017-07-21
# 48933  Entire home/apt    150               1                160  2019-06-09
# 48934  Entire home/apt    135               5                 53  2019-06-22
# 48935     Private room     85               2                188  2019-06-23
# 48936     Private room     89               4                167  2019-06-24
# 48937     Private room     85               2                113  2019-07-05
# 48938  Entire home/apt    120              90                 27  2018-10-31
# 48939  Entire home/apt    140               2                148  2019-06-29
# 48940  Entire home/apt    215               2                198  2019-06-28
# 48941     Private room    140               1                260  2019-07-01
# 48942  Entire home/apt     99               3                 53  2019-06-22
# 48943  Entire home/apt    190               7                  0         NaN
# 48944  Entire home/apt    299               3                  9  2011-12-28
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.38                               2               355
# 1                   0.00                               1               365
# 2                   4.64                               1               194
# 3                   0.10                               1                 0
# 4                   0.59                               1               129
# 5                   0.40                               1                 0
# 6                   3.47                               1               220
# 7                   0.99                               1                 0
# 8                   1.33                               4               188
# 9                   0.43                               1                 6
# 10                  1.50                               1                39
# 11                  1.34                               3               314
# 12                  0.91                               1               333
# 13                  0.22                               1                 0
# 14                  1.20                               1                46
# 15                  1.72                               1               321
# 16                  2.12                               1                12
# 17                  4.44                               1                21
# 18                  0.00                               2               249
# 19                  0.07                               1                 0
# 48925               0.38                               2               355
# 48926               0.00                               1               365
# 48927               4.64                               1               194
# 48928               0.10                               1                 0
# 48929               0.59                               1               129
# 48930               0.40                               1                 0
# 48931               3.47                               1               220
# 48932               0.99                               1                 0
# 48933               1.33                               4               188
# 48934               0.43                               1                 6
# 48935               1.50                               1                39
# 48936               1.34                               3               314
# 48937               0.91                               1               333
# 48938               0.22                               1                 0
# 48939               1.20                               1                46
# 48940               1.72                               1               321
# 48941               2.12                               1                12
# 48942               4.44                               1                21
# 48943               0.00                               2               249
# 48944               0.07                               1                 0

# %%
#Drop duplicate rows
df_unique=df.drop_duplicates()
df_unique.shape
print("Dimensi setelah drop duplicates:", df_unique.shape)
# Out:
# Dimensi setelah drop duplicates: (48920, 16)

# %% [markdown]
# ##Unique Value

# %%
#let's explore some columns to see unique values
print("\nRoom type : ", df['room_type'].unique())
print("\nMinimum night : ", df['minimum_nights'].unique())
print("\nNeigbourhood : ", df["neighbourhood"].unique())
# Out:
# Room type :  ['Entire home/apt' 'Private room' 'Shared room']
#
# Minimum night :  [   1    3   10   45    2    5    4   90    7   14   60   29   30  180
#     9   31    6   15    8   26   28  200   50   17   21   11   25   13
#    35   27   18   20   40   44   65   55  120  365  122   19  240   88
#   115  150  370   16   80  181  265  300   59  185  360   56   12   70
#    39   24   32 1000  110  270   22   75  250   62   23 1250  364   74
#   198  100  500   43   91  480   53   99  160   47  999  186  366   68
#    93   87  183  299  175   98  133  354   42   33   37  225  400  105
#   184  153  134  222   58  210  275  182  114   85   36]
#
# Neigbourhood :  ['Midtown' 'Harlem' 'Clinton Hill' 'East Harlem' 'Murray Hill'
#  'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side' 'Chinatown'
#  'South Slope' 'West Village' 'Williamsburg' 'Fort Greene' 'Chelsea'
#  'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood' 'East Village'
#  'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay'
#  "HELL'S KITCHEN" 'SoHo' 'Upper East Side' 'Prospect Heights'
#  'CLINTON HILL ' 'Washington Heights' 'Woodside' 'Brooklyn Heights'
#  'Clinton Hill ' 'Carroll Gardens' 'Gowanus' 'Flatlands' 'Cobble Hill'
#  'Flushing' 'Boerum Hill' 'Sunnyside' 'DUMBO' 'St. George' 'Highbridge'
#  'Financial District' 'Ridgewood' 'Morningside Heights' 'Jamaica'
#  'Middle Village' 'NoHo' 'Ditmars Steinway' 'Flatiron District'
#  'Roosevelt Island' 'Greenwich Village' 'Little Italy' 'East Flatbush'
#  'Tompkinsville' 'Astoria' 'Kensington' 'Clason Point' 'Eastchester'
#  'Kingsbridge' 'Two Bridges' 'Queens Village' 'Rockaway Beach'
#  'Forest Hills' 'Nolita' 'Woodlawn' 'University Heights' 'Gravesend'
#  'Gramercy' 'Allerton' 'East New York' 'Theater District'
#  'Concourse Village' 'Sheepshead Bay' 'Emerson Hill' 'Fort Hamilton'
#  'Bensonhurst' 'Tribeca' 'Shore Acres' 'Sunset Park' 'Concourse'
#  'Elmhurst' 'Brighton Beach' 'Jackson Heights' 'Cypress Hills'
#  'St. Albans' 'Arrochar' 'Rego Park' 'Wakefield' 'Clifton' 'Bay Ridge'
#  'Graniteville' 'Spuyten Duyvil' 'Stapleton' 'Briarwood' 'Ozone Park'
#  'Columbia St' 'Vinegar Hill' 'Mott Haven' 'Longwood' 'Canarsie'
#  'Battery Park City' 'Civic Center' 'East Elmhurst' 'New Springville'
#  'Morris Heights' 'Arverne' 'Cambria Heights' 'Tottenville'
#  'Mariners Harbor' 'Concord' 'Borough Park' 'Bayside' 'Downtown Brooklyn'
#  'Port Morris' 'Fieldston' 'Kew Gardens' 'Midwood' 'College Point'
#  'Mount Eden' 'City Island' 'Glendale' 'Port Richmond' 'Red Hook'
#  'Richmond Hill' 'Bellerose' 'Maspeth' 'Williamsbridge' 'Soundview'
#  'Woodhaven' 'Woodrow' 'Co-op City' 'Stuyvesant Town' 'Parkchester'
#  'North Riverdale' 'Dyker Heights' 'Bronxdale' 'Sea Gate' 'Riverdale'
#  'Kew Gardens Hills' 'Bay Terrace' 'Norwood' 'Claremont Village'
#  'Whitestone' 'Fordham' 'Bayswater' 'Navy Yard' 'Brownsville'
#  'Eltingville' 'Fresh Meadows' 'Mount Hope' 'Lighthouse Hill'
#  'Springfield Gardens' 'Howard Beach' 'Belle Harbor' 'Jamaica Estates'
#  'Van Nest' 'Morris Park' 'West Brighton' 'Far Rockaway'
#  'South Ozone Park' 'Tremont' 'Corona' 'Great Kills' 'Manhattan Beach'
#  'Marble Hill' 'Dongan Hills' 'Castleton Corners' 'East Morrisania'
#  'Hunts Point' 'Neponsit' 'Pelham Bay' 'Randall Manor' 'Throgs Neck'
#  'Todt Hill' 'West Farms' 'Silver Lake' 'Morrisania' 'Laurelton'
#  'Grymes Hill' 'Holliswood' 'Pelham Gardens' 'Belmont' 'Rosedale'
#  'Edgemere' 'New Brighton' 'Midland Beach' 'Baychester' 'Melrose'
#  'Bergen Beach' 'Richmondtown' 'Howland Hook' 'Schuylerville'
#  'Coney Island' 'New Dorp Beach' "Prince's Bay" 'South Beach' 'Bath Beach'
#  'Jamaica Hills' 'Oakwood' 'Castle Hill' 'Hollis' 'Douglaston' 'Huguenot'
#  'Olinville' 'Edenwald' 'Grant City' 'Westerleigh'
#  'Bay Terrace, Staten Island' 'Westchester Square' 'Little Neck'
#  'Fort Wadsworth' 'Rosebank' 'Unionport' 'Mill Basin' 'Arden Heights'
#  "Bull's Head" 'New Dorp' 'Rossville' 'Breezy Point' 'Willowbrook'
#  'WILLIAMSBURG' 'BUSHWICK']

# %% [markdown]
# Lakukan pembersihan data

# %%
#1. missing values kolom Neigbourhood
print("Jumlah Missing Values per Kolom:\n", df.isna().sum())

df.dropna(subset=['neighbourhood'], inplace=True)
# Out:
# Jumlah Missing Values per Kolom:
#  index                                 0
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10058
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#2. duplicate values untuk semua kolom
# Cek berapa banyak data terduplikasi
print("\nJumlah baris duplikat sebelum dibersihkan:", df.duplicated().sum())

# Menghapus semua baris yang duplikat
df.drop_duplicates(inplace=True)

# Verifikasi pembersihan
print("\nDimensi data setelah pembersihan:", df.shape)
# Out:
# Jumlah baris duplikat sebelum dibersihkan: 20
#
# Dimensi data setelah pembersihan: (48920, 16)

# %% [markdown]
# #Lab 04 - More Cleansing and Resolving
#
# Selanjutnya kita unggah file referensi, dan akan kita gunakan kolom `neighbourhood` untuk mendapatkan informasi `neighbourhood_group` dari data referensi.

# %% [markdown]
# Skenario untuk pengolahan dataframe
# 1. Load reference
# 2. Quick check, rename nama kolom
# 3. Join
# 4. Cek hasil dan menangani data yang tidak ditemukan
#
# Beberapa pertanyaan untuk latihan :
# 1. Berapa baris hasil join data a dan data b?
# 2. Ada berapa yang tidak ketemu hasil combine-nya?
# 3. Apa value kolom col1 untuk row tertentu? (hasil combine)

# %%
ref_file = 'https://raw.githubusercontent.com/urfie/DataAnalytics/main/ref_neighbourhood.csv'
df_ref = pd.read_csv(ref_file)

# %% [markdown]
# Lakukan quick check terhadap data yang di-load

# %%
df_ref.shape
# Out:
# (230, 2)

# %%
df_ref.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood'], dtype='object')

# %%
df_ref.head()
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester
# 2               Bronx       Belmont
# 3               Bronx     Bronxdale
# 4               Bronx   Castle Hill

# %% [markdown]
# Join the dataframes

# %%
airbnb = pd.merge(df_unique, df_ref, on='neighbourhood', how='left')

# %%
airbnb.shape
# Out:
# (48920, 17)

# %%
#show how many null values for each columns
airbnb.isna().sum()
# Out:
# index                                 0
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10056
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# neighbourhood_group                  10
# dtype: int64

# %% [markdown]
# Tampilkan nilai kolom `neighbourhood` dari record-record yang tidak ditemukan di data referensi.

# %%
#show the 'neighbourhood' column for unresolved data
airbnb.loc[airbnb.neighbourhood_group.isna(),'neighbourhood']
# Out:
# 56       HELL'S KITCHEN
# 63        CLINTON HILL
# 91        Clinton Hill
# 110       Clinton Hill
# 166       Clinton Hill
# 48767      WILLIAMSBURG
# 48801      WILLIAMSBURG
# 48822      WILLIAMSBURG
# 48830      WILLIAMSBURG
# 48876          BUSHWICK
# Name: neighbourhood, dtype: object

# %% [markdown]
# Apa yang harus dilakukan dengan data tersebut?
# - standarisasi data : trim & lower
# - kedua hal tersebut perlu dilakukan terhadap dataset maupun referensinya

# %%
#trim and change to lowercase - reference data

df_ref['neighbourhood'] = df_ref['neighbourhood'].str.strip().str.lower()

# %%
#trim and change to lowercase - dataset

df_unique['neighbourhood'] = df_unique['neighbourhood'].str.strip().str.lower()

# %% [markdown]
# Join ulang dan cek hasilnya

# %%
#Join ulang
airbnb = pd.merge(df_unique, df_ref, on='neighbourhood', how='left')

# %%
#Check unmatched
print("Jumlah Unmatched neighbourhood_group:", airbnb['neighbourhood_group'].isna().sum())
# Out:
# Jumlah Unmatched neighbourhood_group: 0

# %% [markdown]
# #Lab 05 - Analyze & Visualize
#
# Aggregation and Visualization
#
# - Grouping dan Agregat
# - Visualisasikan

# %% [markdown]
# ##Analisis : grouping & Agregasi
#
# Beberapa pertanyaan yang akan kita jawab :
# - Ada berapa neighbourhood group?
# - Ada berapa listing dalam tiap neighbourhood group?
# - Berapa rata2 availability, maksimum review perbulan, mayoritas minimum night, harga maksimum untuk tiap neighbourhood group?
# - Ada berapa room type? Berapa jumlah listing untuk masing2 room type dalam tiap2 neighbourhood group?
# - Berapa rata2 availability, maksimum review perbulan, mayoritas minimum night, harga maksimum untuk masing2 room type dalam tiap neighbourhood group?

# %%
#Jumlah neighbourhood group
airbnb['neighbourhood_group'].unique()
# Out:
# array(['Manhattan', 'Brooklyn', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
#Rata2 availability untuk tiap neighbourhood group
grouped = airbnb.groupby(["neighbourhood_group"])
grouped.agg(
    avg_availability=('availability_365','mean')
   )#.reset_index()
# Out:
#                      avg_availability
# neighbourhood_group
# Bronx                      165.758937
# Brooklyn                   100.249292
# Manhattan                  111.978687
# Queens                     144.451818
# Staten Island              199.678284

# %%
#Maksimum review-per-bulan, mayoritas minimum night, harga maksimum untuk tiap neighbourhood group
grouped.agg(
    max_reviews=('reviews_per_month','max')
   )#.reset_index()
# Out:
#                      max_reviews
# neighbourhood_group
# Bronx                      10.34
# Brooklyn                   14.00
# Manhattan                  58.50
# Queens                     20.94
# Staten Island              10.12

# %%
#Jumlah room type
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
#Rata2 availability untuk tiap room type & neighbourhood group

avg_availability_grouped = airbnb.groupby(['neighbourhood_group', 'room_type'])['availability_365'].mean().reset_index()

# %%
#Maksimum review-per-bulan, mayoritas minimum night, harga maksimum untuk tiap room type & neighbourhood group

detailed_agg_grouped = airbnb.groupby(['neighbourhood_group', 'room_type']).agg(
    max_reviews=('reviews_per_month', 'max'),
    majority_min_night=('minimum_nights', lambda x: x.mode()[0] if not x.mode().empty else None),
    max_price=('price', 'max')
).reset_index()

display(detailed_agg_grouped)
# Out:
#    neighbourhood_group        room_type  max_reviews  majority_min_night  \
# 0                Bronx  Entire home/apt        10.34                   2
# 1                Bronx     Private room         8.37                   1
# 2                Bronx      Shared room         6.82                   1
# 3             Brooklyn  Entire home/apt        13.33                   2
# 4             Brooklyn     Private room        14.00                   1
# 5             Brooklyn      Shared room         6.54                   1
# 6            Manhattan  Entire home/apt        14.00                   2
# 7            Manhattan     Private room        58.50                   1
# 8            Manhattan      Shared room        10.77                   1
# 9               Queens  Entire home/apt        15.78                   2
# 10              Queens     Private room        20.94                   1
# 11              Queens      Shared room        10.60                   1
# 12       Staten Island  Entire home/apt         9.10                   2
# 13       Staten Island     Private room        10.12                   1
# 14       Staten Island      Shared room         5.51                   2
#
#     max_price
# 0        1000
# 1        2500
# 2         800
# 3       10000
# 4        7500
# 5         725
# 6       10000
# 7        9999
# 8        1000
# 9        2600
# 10      10000
# 11       1800
# 12       5000
# 13        300
# 14        150

# %% [markdown]
# ##Visualisasi
#
# - Jumlah host per room type
# - Jumlah host per neighbourhood group
# - Rata2, minimum, maksimum availability per room type
# - Rata2, minimum, maksimum availability per neighbourhood group

# %%
#Jumlah host per room type
plt.figure(figsize=(5,5))
sns.countplot(x=airbnb['room_type'])
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
#Rata2, minimum, maksimum availability per room type
plt.figure(figsize=(6,6))
sns.boxplot(data=airbnb, x='room_type',y='availability_365')
# Out:
# <Axes: xlabel='room_type', ylabel='availability_365'>

# %%
#Jumlah host per neighbourhood group
plt.figure(figsize=(8, 5))
sns.countplot(data=airbnb, x='neighbourhood_group')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
#Rata2, minimum, maksimum availability per neighbourhood_group
plt.figure(figsize=(8, 6))
sns.boxplot(data=airbnb, x='neighbourhood_group', y='availability_365')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='availability_365'>

# %% [markdown]
# #Miscellaneous

# %% [markdown]
# ##Menyimpan ke file
#
# Menyimpan dataframe ke dalam file dilakukan dengan perintah `DataFrame.to_`*formatfile*
#
#
# Misalnya, untuk menyimpan file ke format JSON, dapat dilakukan dengan `df.to_json(namafile)`

# %%
airbnb.head().to_json('json_val.json', orient='values') #other option : columns, records, split, index
